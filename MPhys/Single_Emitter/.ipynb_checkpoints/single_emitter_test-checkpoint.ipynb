# %%
import drjit as dr
import mitsuba as mi
mi.set_variant('llvm_ad_rgb')
mi.variants()
# Out:
# ['scalar_rgb', 'scalar_spectral', 'llvm_ad_rgb', 'llvm_mono', 'scalar_mono']

# %%
scene = mi.load_file("./two_mirrors.xml")
original_image = mi.render(scene)
import matplotlib.pyplot as plt
plt.figure(figsize = (20,20))
plt.axis('off')
plt.imshow(original_image ** (1.0 / 2.2));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
scene = mi.load_file("./real_geometry.xml")
original_image = mi.render(scene)
import matplotlib.pyplot as plt
plt.figure(figsize = (20,20))
plt.axis('off')
plt.imshow(original_image ** (1.0 / 2.2));
# Out:
#   Cell In [3], line 21
#     ScalarVector3f fixed_dir = ScalarVector3f(0.f, 0.f, 1.f);
#                                                ^
# SyntaxError: invalid decimal literal
