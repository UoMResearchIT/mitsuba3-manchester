# %%
import mitsuba as mi
mi.set_variant('cuda_mono')
scene = mi.load_file("richGeo.xml")
original_image = mi.render(scene)
import matplotlib.pyplot as plt
plt.figure(figsize = (20,20))
plt.axis('off')
plt.imshow(original_image ** (1.0 / 2.2));
# Out:
# <span style="font-family: monospace; color: #f55">2023-04-17 15:48:04 WARN  wrk6  [HDRFilm] Monochrome mode enabled, setting film output pixel format to &apos;luminance&apos; (was rgb).</span>
